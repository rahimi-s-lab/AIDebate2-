# %% [markdown]
# This notebook is used to obtain the tweets

# %% [markdown]
# ## Setting up ##

# %%
# import modules 
import pandas as pd 
import tweepy 
import pickle

# %% [markdown]
# ## Scraping the tweets ##

# %%
# function to display data of each tweet
def printtweetdata(n, ith_tweet):
    print()
    print(f"Tweet {n}:")
    print(f"Username:{ith_tweet[0]}")
    print(f"Description:{ith_tweet[1]}")
    print(f"Location:{ith_tweet[2]}")
    print(f"Following Count:{ith_tweet[3]}")
    print(f"Follower Count:{ith_tweet[4]}")
    print(f"Total Tweets:{ith_tweet[5]}")
    print(f"Retweet Count:{ith_tweet[6]}")
    print(f"Tweet Text:{ith_tweet[7]}")
    print(f"Hashtags Used:{ith_tweet[8]}")

# %%
# function to perform data extraction
def scrape(words, date_since, numtweet):
    # Creating DataFrame using pandas
    db = pd.DataFrame(columns=[
        'username', 'description', 'location', 'following', 'followers',
        'totaltweets', 'retweetcount', 'text', 'hashtags'
    ])

    # We are using .Cursor() to search through twitter for the required tweets.
    # The number of tweets can be restricted using .items(number of tweets)
    tweets = tweepy.Cursor(api.search_30_day,environment_name='Development',
                           q=words,
                           lang="en",
                           since=date_since,
                           tweet_mode='extended').items(numtweet)#.items(numtweet)
    ##This  is for premium
    tweets = tweepy.Cursor(api.search_30_day,environment_name='', ## Give the environment name as it is
                           query=words,
                           fromDate='202012140000',
                          toDate='202101022200').items()#.items(numtweet)
    
    
    # .Cursor() returns an iterable object. Each item in
    # the iterator has various attributes that you can access to
    # get information about each tweet
    list_tweets = [tweet for tweet in tweets]
    print("Total tweets for ",words)
    # Counter to maintain Tweet Count
    i = 1

    # we will iterate over each tweet in the list for extracting information about each tweet
    for tweet in list_tweets:
        username = tweet.user.screen_name
        description = tweet.user.description
        location = tweet.user.location
        following = tweet.user.friends_count
        followers = tweet.user.followers_count
        totaltweets = tweet.user.statuses_count
        retweetcount = tweet.retweet_count
        hashtags = tweet.entities['hashtags']

        # Retweets can be distinguished by a retweeted_status attribute,
        # in case it is an invalid reference, except block will be executed
        try:
            text = tweet.retweeted_status.full_text
        except AttributeError:
            try:
                text = tweet.full_text
            except:
                continue
        hashtext = list()
        for j in range(0, len(hashtags)):
            hashtext.append(hashtags[j]['text'])

        # Here we are appending all the extracted information in the DataFrame
        ith_tweet = [
            username, description, location, following, followers, totaltweets,
            retweetcount, text, hashtext
        ]
        db.loc[len(db)] = ith_tweet

        # Function call to print tweet data on screen
        printtweetdata(i, ith_tweet)
        i = i + 1
    filename = words + '30scraped_tweets.csv'

    # we will save our database as a CSV file.
    db.to_csv(filename,sep ='\t')
    return list_tweets

# %%
# Enter your own credentials obtained
# from your developer account
consumer_key = ""
consumer_secret = ""
access_key = ""
access_secret = ""
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_key, access_secret)
api = tweepy.API(auth)

# # Enter Hashtag and initial date
# print("Enter Twitter HashTag to search for")
words = "AI Debate" #input()
# print("Enter Date since The Tweets are required in yyyy-mm--dd")
date_since = "2020-10-23"

# # number of tweets you want to extract in one run
numtweet = 5000
x = scrape(words, date_since, numtweet)
# print('Scraping has completed!')
# Out:
# Total tweets for  AI Debate

# %%
len(x)
# Out:
# 5861

# %%
def download(word= "AIDebate2"):
    date_since = "2020-10-23"
    numtweet = 2000
    x = scrape(word, date_since, numtweet)
    print(len(x))
    with open(word + 'query.pkl','wb') as f:
        pickle.dump(x,f)

# %%
with open('AI Debatebiggerquery.pkl','wb') as f:
    pickle.dump(x,f)

# %%
download(word = 'aidebate2')
# Out:
# Total tweets for  aidebate2
#
# Tweet 1:
# Username:luislamb
# Description:Full Professor, Foundations of CS & #AI; PhD Computer Science from @imperialcollege (2000); Secretary of Innovation, Science & Tech, Rio Grande do Sul, Brazil
# Location:Porto Alegre, Brazil
# Following Count:1728
# Follower Count:1837
# Total Tweets:7676
# Retweet Count:2
# Tweet Text:"Leading computer scientists debate the next steps for AI in 2021"
#
# Ben Dickson @bendee983, VentureBeat: https://t.co/hPfJPC2v6X
#
# #AIDebate #AIDebate2 #MontrealAI
# Hashtags Used:[]
#
# Tweet 2:
# Username:ak_panda
# Description:”I am always doing things I can't do, ...that's how I get to do them.” Pablo Picasso
# Location:California, USA
# Following Count:2276
# Follower Count:1087
# Total Tweets:21267
# Retweet Count:6
# Tweet Text:wonderful that #AIDebate2 is inspiring people to read more cognitive science! https://t.co/8RK7pDXKiD
# Hashtags Used:['AIDebate2']
#
# Tweet 3:
# Username:Bruce_Horn
# ...
